# %% [markdown]
# # Análisis Exploratorio de Datos - Spotify

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.read_csv("SpotifyFeatures.csv") # primera lectura
# Out:
#         genre               artist_name                        track_name  \
# 0       Movie            Henri Salvador       C'est beau de faire un Show
# 1       Movie         Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2       Movie           Joseph Williams    Don't Let Me Be Lonely Tonight
# 3       Movie            Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4       Movie              Fabien Nataf                         Ouverture
# ...       ...                       ...                               ...
# 232720   Soul                     Slave                      Son Of Slide
# 232721   Soul  Jr Thomas & The Volcanos                      Burning Fire
# 232722   Soul              Muddy Waters    (I'm Your) Hoochie Coochie Man
# 232723   Soul                   R.LUM.R                     With My Words
# 232724   Soul            Mint Condition    You Don't Have To Hurt No More
#
#                       track_id  popularity  acousticness  danceability  \
# ...

# %%
df=pd.read_csv("SpotifyFeatures.csv") # almacenando variable

# %%
df.columns
# Out:
# Index(['genre', 'artist_name', 'track_name', 'track_id', 'popularity',
#        'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232725 entries, 0 to 232724
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   genre             232725 non-null  object
#  1   artist_name       232725 non-null  object
#  2   track_name        232725 non-null  object
#  3   track_id          232725 non-null  object
#  4   popularity        232725 non-null  int64
#  5   acousticness      232725 non-null  float64
#  6   danceability      232725 non-null  float64
#  7   duration_ms       232725 non-null  int64
#  8   energy            232725 non-null  float64
#  9   instrumentalness  232725 non-null  float64
#  10  key               232725 non-null  object
#  11  liveness          232725 non-null  float64
#  12  loudness          232725 non-null  float64
#  13  mode              232725 non-null  object
#  14  speechiness       232725 non-null  float64
# ...

# %%
df.describe()
# Out:
#           popularity   acousticness   danceability   duration_ms  \
# count  232725.000000  232725.000000  232725.000000  2.327250e+05
# mean       41.127502       0.368560       0.554364  2.351223e+05
# std        18.189948       0.354768       0.185608  1.189359e+05
# min         0.000000       0.000000       0.056900  1.538700e+04
# 25%        29.000000       0.037600       0.435000  1.828570e+05
# 50%        43.000000       0.232000       0.571000  2.204270e+05
# 75%        55.000000       0.722000       0.692000  2.657680e+05
# max       100.000000       0.996000       0.989000  5.552917e+06
#
#               energy  instrumentalness       liveness       loudness  \
# count  232725.000000     232725.000000  232725.000000  232725.000000
# mean        0.570958          0.148301       0.215009      -9.569885
# std         0.263456          0.302768       0.198273       5.998204
# min         0.000020          0.000000       0.009670     -52.457000
# ...

# %% [markdown]
# ### Género más popular

# %%
# Identificar valores en la columna genre

df['genre'].unique()
# Out:
# array(['Movie', 'R&B', 'A Capella', 'Alternative', 'Country', 'Dance',
#        'Electronic', 'Anime', 'Folk', 'Blues', 'Opera', 'Hip-Hop',
#        "Children's Music", 'Children’s Music', 'Rap', 'Indie',
#        'Classical', 'Pop', 'Reggae', 'Reggaeton', 'Jazz', 'Rock', 'Ska',
#        'Comedy', 'Soul', 'Soundtrack', 'World'], dtype=object)

# %%
# Calcular el promedio de popularidad para cada género y ordenarlo de forma descendente

promedios_por_genero = df.groupby('genre')['popularity'].mean().sort_values(ascending = False)
print(promedios_por_genero)
# Out:
# genre
# Pop                 66.590667
# Rap                 60.533795
# Rock                59.619392
# Hip-Hop             58.423131
# Dance               57.275256
# Indie               54.701561
# Children’s Music    54.659040
# R&B                 52.308719
# Alternative         50.213430
# Folk                49.940209
# Soul                47.027836
# Country             46.100416
# Jazz                40.824383
# Electronic          38.056095
# Reggaeton           37.742915
# Reggae              35.589328
# World               35.524077
# Blues               34.742879
# Soundtrack          33.954800
# Classical           29.282195
# Ska                 28.612351
# Anime               24.258729
# Comedy              21.342630
# Opera               13.335628
# Movie               12.174097
# A Capella            9.302521
# Children's Music     4.252637
# Name: popularity, dtype: float64

# %%
# Gráfica

plt.figure(figsize=(15,10))
plt.barh(promedios_por_genero.index, promedios_por_genero, color=plt.cm.inferno_r(promedios_por_genero/100))
plt.xlabel('Popularidad promedio')
plt.ylabel('Género musical')
plt.title('Popularidad según género musical')
# Out:
# Text(0.5, 1.0, 'Popularidad según género musical')

# %% [markdown]
# ### Mapa de calor
#
# Cómo se relacionan las características de las canciones entre sí.

# %%
plt.figure(figsize=(15,10))
plt.title("Correlación entre características de las canciones de Spotify")
sns.heatmap(df.corr(), annot=True, cmap='inferno')
plt.show()
# Out:
# C:\Users\tinch\AppData\Local\Temp\ipykernel_11228\1982895556.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap='inferno')

# %% [markdown]
# # Duración promedio de las canciones por género

# %%
duracion_promedio_genero = df.groupby('genre')['duration_ms'].mean()
print(duracion_promedio_genero/1000)
# Out:
# genre
# A Capella           204.467697
# Alternative         233.241364
# Anime               229.937068
# Blues               251.931826
# Children's Music    142.726774
# Children’s Music    232.554444
# Classical           310.339984
# Comedy              235.305210
# Country             217.237527
# Dance               226.264942
# Electronic          269.195980
# Folk                235.805457
# Hip-Hop             219.981913
# Indie               224.150374
# Jazz                265.645270
# Movie               210.405352
# Opera               259.161092
# Pop                 220.859160
# R&B                 225.748130
# Rap                 219.853858
# Reggae              239.503539
# Reggaeton           232.037139
# Rock                237.003227
# Ska                 191.548604
# Soul                234.714359
# Soundtrack          192.611749
# World               315.327892
# Name: duration_ms, dtype: float64

# %% [markdown]
# ## Medidas descriptivas según duración de tiempo de los géneros más populares

# %%
pop_descripcion = df[df['genre'] == 'Pop']['duration_ms'].describe() # valores en milisegundos para el género Pop
print(pop_descripcion/1000) # valores en segundos
# Out:
# count      9.386000
# mean     220.859160
# std       46.591265
# min       21.547000
# 25%      191.967750
# 50%      215.279000
# 75%      242.303500
# max      723.573000
# Name: duration_ms, dtype: float64

# %%
rap_descripcion = df[df['genre'] == 'Rap']['duration_ms'].describe() # valores en milisegundos para el género Rap
print(rap_descripcion/1000)
# Out:
# count      9.232000
# mean     219.853858
# std       57.890479
# min       39.640000
# 25%      183.790000
# 50%      214.966000
# 75%      250.687000
# max      760.973000
# Name: duration_ms, dtype: float64

# %%
rock_descripcion = df[df['genre'] == 'Rock']['duration_ms'].describe() # valores en milisegundos para el género Rock
print(rock_descripcion/1000)
# Out:
# count       9.272000
# mean      237.003227
# std        66.325046
# min        41.455000
# 25%       197.825750
# 50%       226.303000
# 75%       262.533000
# max      1412.451000
# Name: duration_ms, dtype: float64
