# %% [markdown]
# # Análisis Exploratorio de Datos - Spotify

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.read_csv("SpotifyFeatures.csv") # primera lectura

# %%
df=pd.read_csv("SpotifyFeatures.csv") # almacenando variable

# %%
df.columns

# %%
df.info()

# %%
df.describe()

# %% [markdown]
# ### Top 20 canciones más populares

# %%
df.sort_values('popularity', ascending=False).head(20) # vistazo al top 20 canciones más populares

# %% [markdown]
# ### Top 20 Canciones más bailables

# %%
df.sort_values('danceability', ascending=False).head(20)

# %% [markdown]
# ### Mapa de calor
#
# Correlación entre variables

# %%
plt.figure(figsize=(15,6))
plt.title("Correlación entre variables")
sns.heatmap(df.corr(), annot=True, cmap='inferno')
plt.show()
# Out:
# C:\Users\tinch\AppData\Local\Temp\ipykernel_11632\4128744974.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap='inferno')
